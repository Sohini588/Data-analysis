# %%
import pandas as pd
import seaborn as sns
import numpy as np
data=pd.read_csv("/content/WorldCupMatches.csv")
df=pd.DataFrame(data)
data
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
a=(len(data))
print(a)
b=(len(data.columns))
print(b)
# Out:
# 4572
# 20

# %%
data[20:30]
# Out:
#       Year              Datetime              Stage                  Stadium  \
# 20  1934.0  27 May 1934 - 16:30   Preliminary round                 San Siro
# 21  1934.0  27 May 1934 - 16:30   Preliminary round                Littorale
# 22  1934.0  27 May 1934 - 16:30   Preliminary round           Giovanni Berta
# 23  1934.0  27 May 1934 - 16:30   Preliminary round           Luigi Ferraris
# 24  1934.0  27 May 1934 - 16:30   Preliminary round            Nazionale PNF
# 25  1934.0  27 May 1934 - 16:30   Preliminary round                 Littorio
# 26  1934.0  31 May 1934 - 16:30      Quarter-finals  Stadio Benito Mussolini
# 27  1934.0  31 May 1934 - 16:30      Quarter-finals                 San Siro
# 28  1934.0  31 May 1934 - 16:30      Quarter-finals           Giovanni Berta
# 29  1934.0  31 May 1934 - 16:30      Quarter-finals                Littorale
#
#          City  Home Team Name  Home Team Goals  Away Team Goals  \
# ...

# %%
data["Away Team Goals"].mean()
# Out:
# 1.022300469483568

# %%
data["Away Team Goals"].median()
# Out:
# 1.0

# %%
data['Away Team Goals'].mode()[0]
# Out:
# 1.0

# %%
data["Away Team Goals"].max()
# Out:
# 7.0

# %%
data["Away Team Goals"].min()
# Out:
# 0.0

# %%
df.isnull()     #show null values
# Out:
#        Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0     False     False  False    False  False           False            False
# 1     False     False  False    False  False           False            False
# 2     False     False  False    False  False           False            False
# 3     False     False  False    False  False           False            False
# 4     False     False  False    False  False           False            False
# ...     ...       ...    ...      ...    ...             ...              ...
# 4567   True      True   True     True   True            True             True
# 4568   True      True   True     True   True            True             True
# 4569   True      True   True     True   True            True             True
# 4570   True      True   True     True   True            True             True
# 4571   True      True   True     True   True            True             True
#
# ...

# %%
df.isnull().sum()     #print the sum of null values
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
df["Away Team Goals"].fillna(df["Away Team Goals"].mean(),inplace=True)
print(df)
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
df["Away Team Goals"].fillna(df["Away Team Goals"].median(),inplace=True)
print(df)
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
data.shape
# Out:
# (4572, 20)

# %%
data.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000      4572.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         0.469265   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         1.022300   30000.000000
# 50%    1990.000000         2.000000         1.022300   41579.500000
# 75%    2002.000000         3.000000         1.022300   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
print(df["Home Team Goals"].corr(df["Away Team Goals"]))
# Out:
# 0.012473988573227714

# %%
import seaborn as sns
sns.boxplot(data["Away Team Goals"])
# Out:
# <Axes: ylabel='Away Team Goals'>

# %%
sns.pairplot(data)

# %%
sns.barplot(data)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
sns.histplot(data=data,x="Away Team Goals",y="Home Team Goals")
plt.show()

# %%
corr = data[["Attendance","Away Team Goals","Home Team Goals"]].corr()
sns.heatmap(corr)
plt.show()

# %%
sns.displot(data["Attendance"], bins=20, kde=True)

# %%
sns.scatterplot(data=data,x="Attendance",y="Home Team Goals")
plt.show()
